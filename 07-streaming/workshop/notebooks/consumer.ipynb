# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'rides'

# %%
from models import Ride, ride_deserializer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from models import Ride, ride_deserializer
#
# ImportError: cannot import name 'ride_deserializer' from 'models' (c:\Users\adilb\OneDrive\Документы\GitHub\data-engineering-zoomcamp\07-streaming\workshop\notebooks\models.py)

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-console',
    value_deserializer=ride_deserializer
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       1 consumer = KafkaConsumer(
#       2     topic_name,
#       3     bootstrap_servers=[server],
#       4     auto_offset_reset='earliest',
#       5     group_id='rides-console',
# ----> 6     value_deserializer=ride_deserializer
#       7 )
#
# NameError: name 'ride_deserializer' is not defined

# %%
next(consumer)
# Out:
# ConsumerRecord(topic='rides', partition=0, leader_epoch=1, offset=0, timestamp=1773517949053, timestamp_type=0, key=None, value={'PULocationID': 186, 'DOLocationID': 79, 'trip_distance': 1.72, 'total_amount': 17.31, 'tpep_pickup_datetime': 1730429702000}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=126, serialized_header_size=-1)
